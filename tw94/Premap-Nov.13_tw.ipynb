# %%
# %matplotlib inline
import os
from astropy.io import fits
import pandas as pd
import os
import sys
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')
import lsst.afw.geom as afwGeom
import lsst.daf.persistence as dafPersist

# %% [markdown]
# # Today we'll use astropy to load a FITS table file, which has information about variable sources in the HiTS DR1.

# %%
datadir='/epyc/users/mrawls/premap2019/hits-dr1'
filename='HiTS_DR1_variables_DM-dataset-subset.fits'
filepath=os.path.join(datadir,filename)

# %%
print(filepath)
# Out:
# /epyc/users/mrawls/premap2019/hits-dr1/HiTS_DR1_variables_DM-dataset-subset.fits

# %%
table=fits.open(filepath)

# %%
header=table[1].header

# %%
columns= table[1].columns
columns
# Out:
# ColDefs(
#     name = 'ID'; format = '17A'
#     name = 'internalID'; format = '25A'
#     name = 'raMedian'; format = 'D'
#     name = 'decMedian'; format = 'D'
#     name = 'Variable_prob'; format = 'D'
#     name = 'Periodic_prob'; format = 'D'
#     name = 'DSCT_Prob'; format = 'E'
#     name = 'EB_Prob'; format = 'D'
#     name = 'ROTVAR_Prob'; format = 'D'
#     name = 'RRLYR_Prob'; format = 'E'
#     name = 'CV_Prob'; format = 'D'
#     name = 'QSO_Prob'; format = 'D'
#     name = 'SNe_Prob'; format = 'E'
#     name = 'Predicted_class'; format = '6A'
#     name = 'ID_feat'; format = '17A'
#     name = 'raMedian_feat'; format = 'D'
#     name = 'decMedian_feat'; format = 'D'
#     name = 'Amplitude'; format = 'D'
#     name = 'AndersonDarling'; format = 'D'
#     name = 'Autocor_length'; format = 'E'
#     name = 'Beyond1Std'; format = 'D'
#     name = 'CAR_mean'; format = 'D'
#     name = 'CAR_sigma'; format = 'D'
#     name = 'CAR_tau'; format = 'D'
#     name = 'Con'; format = 'D'
#     name = 'Eta_e'; format = 'D'
#     name = 'FluxPercentileRatioMid20'; format = 'D'
#     name = 'FluxPercentileRatioMid35'; format = 'D'
#     name = 'FluxPercentileRatioMid50'; format = 'D'
#     name = 'FluxPercentileRatioMid65'; format = 'D'
#     name = 'FluxPercentileRatioMid80'; format = 'D'
#     name = 'Freq1_harmonics_amplitude_0'; format = 'D'
#     name = 'Freq1_harmonics_amplitude_1'; format = 'D'
#     name = 'Freq1_harmonics_amplitude_2'; format = 'D'
#     name = 'Freq1_harmonics_amplitude_3'; format = 'D'
#     name = 'Freq1_harmonics_rel_phase_0'; format = 'E'
#     name = 'Freq1_harmonics_rel_phase_1'; format = 'D'
#     name = 'Freq1_harmonics_rel_phase_2'; format = 'D'
#     name = 'Freq1_harmonics_rel_phase_3'; format = 'D'
#     name = 'Freq2_harmonics_amplitude_0'; format = 'D'
#     name = 'Freq2_harmonics_amplitude_1'; format = 'D'
#     name = 'Freq2_harmonics_amplitude_2'; format = 'D'
#     name = 'Freq2_harmonics_amplitude_3'; format = 'D'
#     name = 'Freq2_harmonics_rel_phase_0'; format = 'E'
#     name = 'Freq2_harmonics_rel_phase_1'; format = 'D'
#     name = 'Freq2_harmonics_rel_phase_2'; format = 'D'
#     name = 'Freq2_harmonics_rel_phase_3'; format = 'D'
#     name = 'Freq3_harmonics_amplitude_0'; format = 'D'
#     name = 'Freq3_harmonics_amplitude_1'; format = 'D'
#     name = 'Freq3_harmonics_amplitude_2'; format = 'D'
#     name = 'Freq3_harmonics_amplitude_3'; format = 'D'
#     name = 'Freq3_harmonics_rel_phase_0'; format = 'E'
#     name = 'Freq3_harmonics_rel_phase_1'; format = 'D'
#     name = 'Freq3_harmonics_rel_phase_2'; format = 'D'
#     name = 'Freq3_harmonics_rel_phase_3'; format = 'D'
#     name = 'Gskew'; format = 'D'
#     name = 'LinearTrend'; format = 'D'
#     name = 'MaxSlope'; format = 'D'
#     name = 'Mean'; format = 'D'
#     name = 'Meanvariance'; format = 'D'
#     name = 'MedianAbsDev'; format = 'D'
#     name = 'MedianBRP'; format = 'D'
#     name = 'PairSlopeTrend'; format = 'D'
#     name = 'PercentAmplitude'; format = 'D'
#     name = 'PercentDifferenceFluxPercentile'; format = 'D'
#     name = 'PeriodGLS'; format = 'D'
#     name = 'PeriodLS'; format = 'D'
#     name = 'PeriodWMCC'; format = 'D'
#     name = 'Period_fit'; format = 'D'
#     name = 'Psi_CS'; format = 'D'
#     name = 'Psi_eta'; format = 'D'
#     name = 'Q31'; format = 'D'
#     name = 'Rcs'; format = 'D'
#     name = 'Skew'; format = 'D'
#     name = 'SlottedA_length'; format = 'D'
#     name = 'SmallKurtosis'; format = 'D'
#     name = 'Std'; format = 'D'
#     name = 'StetsonK'; format = 'D'
#     name = 'StetsonK_AC'; format = 'D'
#     name = 'g-i'; format = 'D'
#     name = 'g-r'; format = 'D'
#     name = 'r-i'; format = 'D'
# )

# %%
ptable=pd.DataFrame(table[1].data)
ptable
# Out:
#                     ID                 internalID    raMedian  decMedian  \
# 0    HiTS095611+020452   Blind15A_26_N1_1715_0146  149.048038   2.081381
# 1    HiTS095645+021135   Blind15A_26_N1_0181_2093  149.190225   2.193068
# 2    HiTS095652+023537  Blind15A_26_S14_1446_0379  149.220445   2.593841
# 3    HiTS095702+023628  Blind15A_26_S14_1253_0945  149.261780   2.607883
# 4    HiTS095726+015556   Blind15A_26_N8_1496_2317  149.361376   1.932343
# 5    HiTS095734+015351   Blind15A_26_N8_1969_2775  149.394743   1.897668
# 6    HiTS095744+013651  Blind15A_26_N20_1353_1224  149.437020   1.614256
# 7    HiTS095746+015823   Blind15A_26_N8_0935_3426  149.442257   1.973122
# 8    HiTS095801+014018  Blind15A_26_N20_0559_2169  149.505980   1.671866
# 9    HiTS095804+015217  Blind15A_26_N15_0080_0224  149.518623   1.871532
# 10   HiTS095809+013536  Blind15A_26_N20_1634_2628  149.539435   1.593359
# 11   HiTS095818+023028   Blind15A_26_S9_0376_1001  149.575959   2.507986
# 12   HiTS095824+013052  Blind15A_26_N25_0466_1383  149.604007   1.514554
# 13   HiTS095828+023805  Blind15A_26_S15_0890_1602  149.619965   2.634973
# 154  HiTS102357-051719  Blind15A_42_N18_0070_2781  155.990095  -5.288829
# 155  HiTS102357-064642  Blind15A_40_N13_1231_3291  155.990562  -6.778481
# 156  HiTS102358-051324  Blind15A_42_N12_1428_2835  155.994019  -5.223586
# 157  HiTS102404-041807  Blind15A_42_S24_0075_1076  156.020636  -4.302175
# 158  HiTS102407-065228  Blind15A_40_N19_0300_3857  156.032235  -6.874634
# 159  HiTS102412-045536   Blind15A_42_S6_1873_1512  156.053127  -4.926806
# 160  HiTS102432-044151  Blind15A_42_S13_0990_0492  156.133920  -4.697616
# 161  HiTS102443-052301  Blind15A_42_N19_1376_1138  156.180870  -5.383641
# 162  HiTS102443-063608   Blind15A_40_N7_1075_3779  156.182220  -6.602472
# 163  HiTS102501-043544  Blind15A_42_S19_1841_2156  156.255521  -4.595699
# 164  HiTS102514-042751  Blind15A_42_S19_0039_2904  156.310131  -4.464279
#
#      Variable_prob  Periodic_prob  DSCT_Prob  EB_Prob  ROTVAR_Prob  \
# 0         0.523601       0.202651        NaN      NaN          NaN
# 1         0.564932       0.635018      0.400    0.100        0.375
# 2         0.962477       0.635836      0.025    0.125        0.750
# 3         0.532390       0.933333      0.550    0.225        0.050
# 4         0.972280       0.889344      0.050    0.175        0.625
# 5         0.598832       0.599606      0.125    0.100        0.625
# 6         0.533333       0.178671        NaN      NaN          NaN
# 7         0.566527       0.137593        NaN      NaN          NaN
# 8         0.500000       0.369948        NaN      NaN          NaN
# 9         1.000000       0.780931      0.000    0.100        0.900
# 10        0.566215       0.146513        NaN      NaN          NaN
# 11        0.566667       0.634808      0.000    0.400        0.600
# 12        0.722405       0.085199        NaN      NaN          NaN
# 13        0.866667       0.833333      0.000    0.375        0.625
# 14        0.623234       0.469525        NaN      NaN          NaN
# 15        0.933230       0.700323      0.050    0.250        0.675
# 16        1.000000       0.999606      0.050    0.200        0.425
# 17        0.500000       0.201556        NaN      NaN          NaN
# 18        0.552524       0.136444        NaN      NaN          NaN
# 19        0.700000       0.390697        NaN      NaN          NaN
# 20        0.933333       0.907046      0.000    0.350        0.600
# 21        0.619107       0.163339        NaN      NaN          NaN
# 22        0.652913       0.552660      0.300    0.100        0.475
# 23        0.589897       0.474910        NaN      NaN          NaN
# 24        0.765210       0.434808        NaN      NaN          NaN
# 25        0.594562       0.669554      0.050    0.050        0.800
# 26        0.733333       0.203924        NaN      NaN          NaN
# 27        0.653742       0.245293        NaN      NaN          NaN
# 28        0.531339       0.221570        NaN      NaN          NaN
# 29        0.500000       0.166780        NaN      NaN          NaN
# ..             ...            ...        ...      ...          ...
# 135       0.666667       0.474835        NaN      NaN          NaN
# 136       0.533333       0.499606        NaN      NaN          NaN
# 137       0.633333       0.779457      0.000    0.425        0.575
# 138       0.633132       0.626243      0.200    0.575        0.150
# 139       0.600000       0.367829        NaN      NaN          NaN
# 140       0.826193       0.104170        NaN      NaN          NaN
# 141       0.600000       0.568351      0.025    0.100        0.775
# 142       0.665386       0.570075      0.000    0.125        0.725
# 161  0.048894  0.882270     0.783464  2.344382  1.295915  1.048466
# 162  0.072124  0.814912     0.779073  0.222479  0.180101  0.042378
# 163  0.060485  0.846812     0.800201  0.337788  0.184168  0.153620
# 164  0.173215  0.831637     0.787809  0.168120  0.047769  0.120351
#
# [165 rows x 82 columns]

# %% [markdown]
# ## Plotting variable sources on top of all the sources we previously found in LSST

# %%
repo = '/epyc/users/mrawls/premap2019/hits-lsst/hits2015/rerun/highres1'
butler = dafPersist.Butler(repo)

# %%
dbName = 'association.db'
dbPath = os.path.join(repo,dbName)

# %%
connection = sqlite3.connect(dbPath)

# %%
objTable = pd.read_sql_query('select diaObjectId, ra, decl, nDiaSources,\
                                gPSFluxMean, gPSFluxMeanErr,\
                                validityEnd, flags,\
                                gTOTFluxMean, gTOTFluxMeanErr\
                                from DiaObject where validityEnd is NULL;',connection)

# %%
print(len(ptable),len(objTable))
# Out:
# 165 110157

# %%
#Get RAs and Decs for objects in the LSST database

ax1Filter = (objTable['decl']>-2)
ax2Filter=(~ax1Filter)

ra1_first=objTable.loc[ax1Filter, 'ra']
dec1_first=objTable.loc[ax1Filter, 'decl']
ra2_first=objTable.loc[ax2Filter, 'ra']
dec2_first=objTable.loc[ax2Filter, 'decl']

# %%
#Get RAs and Decs for objects in the HiTS DR1 table

ax1Filter_second = (ptable['decMedian']>-2)
ax2Filter_second = (~ax1Filter_second)

ra1_second=ptable.loc[ax1Filter_second,'raMedian']
dec1_second=ptable.loc[ax1Filter_second,'decMedian']
ra2_second=ptable.loc[ax2Filter_second,'raMedian']
dec2_second=ptable.loc[ax2Filter_second,'decMedian']

# %%
def plot_objects_on_sky(ra1_first,dec1_first,
                        ra2_first,dec2_first,
                        ra1_second,dec1_second,
                        ra2_second,dec2_second):
    
    '''This function takes two sets of RA and Dec and plots them both on the sky in different colors
    
    It is customized to plot a specific region (thee HiTS fields in two panels)
    "1" and "2" refer to the two panels on this plot
    "first" and "second refer to the two different datasets'''
    #Set up the figure object and two axes
    fig = plt.figure(figsize=(10,10))
    ax1 = plt.subplot2grid((100,100),(0,55), rowspan=50, colspan=45)
    ax2 = plt.subplot2grid((100,100),(0,0), rowspan=90, colspan=50)

    ax1.invert_xaxis()
    ax2.invert_xaxis()
    
    #Plot the first set of RAs and Decs in blue
    ax1.scatter(ra1_first,dec1_first,marker='.',s=0.5,alpha=0.2,c='C0')
    ax2.scatter(ra2_first,dec2_first,marker='.',s=0.5,alpha=0.2,c='C0')

    #Plot the second set of RAs and Decs in orange
    ax1.scatter(ra1_second,dec1_second,marker='.',s=10,alpha=0.8,c='C1')
    ax2.scatter(ra2_second,dec2_second,marker='.',s=10,alpha=0.8,c='C1')
    
    plt.xlabel('RA (deg)')
    plt.ylabel('Dec (deg)')
    plt.title('Coarse overview of where objects are in the sky')

# %%
plot_objects_on_sky(ra1_first,dec1_first,ra2_first,dec2_first,ra1_second,dec1_second,ra2_second,dec2_second)
